# %% [markdown]
# #DATA ANALYSIS AND TURN INTO A PY CODE
#
# We will build real inisghts which will show our data(raw data) into usefull data(processed data) for the users (company)

# %%
import json

# %%
def load_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)
    return data

# %%
data = load_data("data.json")
print(data)
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]}, {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]}, {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]}, {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}], 'pages': [{'id': 101, 'name': 'Python Developers'}, {'id': 102, 'name': 'Data Science Enthusiasts'}, {'id': 103, 'name': 'AI & ML Community'}, {'id': 104, 'name': 'Web Dev Hub'}]}

# %%
from pprint import pprint
pprint(data)
# Out:
# {'pages': [{'id': 101, 'name': 'Python Developers'},
#            {'id': 102, 'name': 'Data Science Enthusiasts'},
#            {'id': 103, 'name': 'AI & ML Community'},
#            {'id': 104, 'name': 'Web Dev Hub'}],
#  'users': [{'friends': [2, 3], 'id': 1, 'liked_pages': [101], 'name': 'Amit'},
#            {'friends': [1, 4], 'id': 2, 'liked_pages': [102], 'name': 'Priya'},
#            {'friends': [1],
#             'id': 3,
#             'liked_pages': [101, 103],
#             'name': 'Rahul'},
#            {'friends': [2], 'id': 4, 'liked_pages': [104], 'name': 'Sara'}]}

# %%
type(data)
# Out:
# dict

# %%
#Function to display users and their connections
def display_users(data):
    for user in data['users']:
        print

# %%
#Function to display users and their connections
def display_users(data):
    print("Users and their connections\n")
    
    for user in data['users']:
        print(f"ID:{user['name']} - {user['name']} is friends with: {user['friends']} and liked pages are {user['liked_pages']}")
    
    print("\nPages Information")
    for page in data['pages']:
        print(f"{page['id']}: {page['name']}")



display_users(data)
# Out:
# Users and their connections
#
# ID:Amit - Amit is friends with: [2, 3] and liked pages are [101]
# ID:Priya - Priya is friends with: [1, 4] and liked pages are [102]
# ID:Rahul - Rahul is friends with: [1] and liked pages are [101, 103]
# ID:Sara - Sara is friends with: [2] and liked pages are [104]
#
# Pages Information
# 101: Python Developers
# 102: Data Science Enthusiasts
# 103: AI & ML Community
# 104: Web Dev Hub
